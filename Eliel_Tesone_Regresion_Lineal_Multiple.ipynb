# %%
import pandas as pd
import numpy as np

# %%
wine = pd.read_csv('winequality-red.csv', sep = ';')
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
from sklearn.linear_model import LinearRegression

# Borrado de la variable objetivo
wine_vif = wine.copy(deep = True)
features = list(wine_vif.columns)
features.remove('quality')#remover esto porque es la variable objetivo
wine_vif = wine_vif[features]

for i in range(len(features)):
    var = features[i]
    fet = features[:]
    fet.remove(var)
    
    x = wine_vif[fet]
    y = wine[var]
    
    model = LinearRegression()
    model.fit(x, y)
    
    vif = 1 / (1 - model.score(x, y))
    
    print ('El valor del VIF para la variable', var, 'es:', vif)
# Out:
# El valor del VIF para la variable fixed acidity es: 7.767511565707904
# El valor del VIF para la variable volatile acidity es: 1.7893896822287916
# El valor del VIF para la variable citric acid es: 3.128022124356086
# El valor del VIF para la variable residual sugar es: 1.7025879081509325
# El valor del VIF para la variable chlorides es: 1.481932329802808
# El valor del VIF para la variable free sulfur dioxide es: 1.9630191414810896
# El valor del VIF para la variable total sulfur dioxide es: 2.1868127885900845
# El valor del VIF para la variable density es: 6.343760185861633
# El valor del VIF para la variable pH es: 3.3297316235827057
# El valor del VIF para la variable sulphates es: 1.4294337493895655
# El valor del VIF para la variable alcohol es: 3.031159819884154

# %%
features = list(wine_vif.columns)
features.remove('fixed acidity')
wine_vif = wine_vif[features]

for i in range(len(features)):
    var = features[i]
    fet = features[:]
    fet.remove(var)
    
    x = wine_vif[fet]
    y = wine[var]
    
    model = LinearRegression()
    model.fit(x, y)
    
    vif = 1 / (1 - model.score(x, y))
    
    print ('El valor del VIF para la variable', var, 'es:', vif)
# Out:
# El valor del VIF para la variable volatile acidity es: 1.7849630819063238
# El valor del VIF para la variable citric acid es: 2.7805565972537205
# El valor del VIF para la variable residual sugar es: 1.3863754802141395
# El valor del VIF para la variable chlorides es: 1.401231582382031
# El valor del VIF para la variable free sulfur dioxide es: 1.9392089227248297
# El valor del VIF para la variable total sulfur dioxide es: 2.069396444386063
# El valor del VIF para la variable density es: 2.430096453653435
# El valor del VIF para la variable pH es: 1.6107751313599323
# El valor del VIF para la variable sulphates es: 1.3963817651769534
# El valor del VIF para la variable alcohol es: 2.136067290546727

# %%
def calculateVIF(data):
    features = list(data.columns)
    num_features = len(features)
    
    model = LinearRegression()
    
    result = pd.DataFrame(index = ['VIF'], columns = features)
    result = result.fillna(0)
    
    for ite in range(num_features):
        x_features = features[:]
        y_featue = features[ite]
        x_features.remove(y_featue)
        
        x = data[x_features]
        y = data[y_featue]
        
        model.fit(data[x_features], data[y_featue])
        
        result[y_featue] = 1/(1 - model.score(data[x_features], data[y_featue]))
    
    return result

wine_vif = wine.copy(deep = True)
features = list(wine_vif.columns)
features.remove('quality')#remover esto porque es la variable objetivo
wine_vif = wine_vif[features]

calculateVIF(wine_vif)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# VIF       7.767512           1.78939     3.128022        1.702588   1.481932
#
#      free sulfur dioxide  total sulfur dioxide  density        pH  sulphates  \
# VIF             1.963019              2.186813  6.34376  3.329732   1.429434
#
#      alcohol
# VIF  3.03116

# %%
def selectDataUsingVIF(data, max_VIF = 5):
    result = data.copy(deep = True)
    
    VIF = calculateVIF(result)
    
    while VIF.as_matrix().max() > max_VIF:
        col_max = np.where(VIF == VIF.as_matrix().max())[1][0]
        features = list(result.columns)
        features.remove(features[col_max])
        result = result[features]
        
        VIF = calculateVIF(result)
        
    return result

calculateVIF(selectDataUsingVIF(wine_vif))
# Out:
# C:\Users\etesone\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# C:\Users\etesone\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   import sys
# C:\Users\etesone\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#      volatile acidity  citric acid  residual sugar  chlorides  \
# VIF          1.784963     2.780557        1.386375   1.401232
#
#      free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# VIF             1.939209              2.069396  2.430096  1.610775   1.396382
#
#       alcohol
# VIF  2.136067
